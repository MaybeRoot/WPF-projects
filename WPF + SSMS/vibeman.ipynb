-- %% [markdown]
-- # [dbo].[Клиент]

-- %%
USE [Vibeman]
GO

-- %%
/****** Object:  Table [dbo].[Клиент]    Script Date: 24.12.2024 22:48:11 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Клиент](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Фамилия] [varchar](50) NULL,
	[Имя] [varchar](50) NULL,
	[Отчество] [varchar](50) NULL,
	[ДатаРождения] [datetime] NULL,
	[Паспорт_серия] [nchar](4) NULL,
	[Паспорт_номер] [nchar](6) NULL,
 CONSTRAINT [PK_Клиент] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[НомернойФонд]

-- %%
/****** Object:  Table [dbo].[НомернойФонд]    Script Date: 24.12.2024 22:48:11 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[НомернойФонд](
	[IDФонда] [int] IDENTITY(1,1) NOT NULL,
	[Этаж] [int] NULL,
	[Номер] [int] NULL,
	[Категория] [varchar](70) NULL,
	[Статус] [varchar](15) NULL,
	[Стоимость] [nvarchar](20) NULL,
 CONSTRAINT [PK_НомернойФонд] PRIMARY KEY CLUSTERED 
(
	[IDФонда] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Пользователи]

-- %%
/****** Object:  Table [dbo].[Пользователи]    Script Date: 24.12.2024 22:48:11 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Пользователи](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Фамилия] [varchar](50) NULL,
	[Имя] [varchar](50) NULL,
	[Отчество] [varchar](50) NULL,
	[Логин] [varchar](50) NULL,
	[Пароль] [varchar](50) NULL,
	[Почта] [varchar](255) NULL,
	[Роль] [varchar](50) NULL,
	[Последний_логин] [datetime] NULL,
	[Статус] [nvarchar](50) NULL,
	[Первый_доступ] [datetime] NULL,
	[Доступ_запрещен] [bit] NULL,
 CONSTRAINT [PK_Пользователи] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Постояльцы]

-- %%
/****** Object:  Table [dbo].[Постояльцы]    Script Date: 24.12.2024 22:48:11 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Постояльцы](
	[IDПостояльца] [int] IDENTITY(1,1) NOT NULL,
	[Клиент] [int] NULL,
	[IDНомерФонд] [int] NULL,
	[ВремяВъезд] [datetime] NULL,
	[ВремяВыезд] [datetime] NULL,
	[IDСотрудник] [int] NULL,
 CONSTRAINT [PK_Постояльцы] PRIMARY KEY CLUSTERED 
(
	[IDПостояльца] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_Постояльцы_Клиент]

-- %%
ALTER TABLE [dbo].[Постояльцы]  WITH CHECK ADD  CONSTRAINT [FK_Постояльцы_Клиент] FOREIGN KEY([Клиент])
REFERENCES [dbo].[Клиент] ([ID])
GO
ALTER TABLE [dbo].[Постояльцы] CHECK CONSTRAINT [FK_Постояльцы_Клиент]
GO

-- %% [markdown]
-- # [FK_Постояльцы_НомернойФонд]

-- %%
ALTER TABLE [dbo].[Постояльцы]  WITH CHECK ADD  CONSTRAINT [FK_Постояльцы_НомернойФонд] FOREIGN KEY([IDНомерФонд])
REFERENCES [dbo].[НомернойФонд] ([IDФонда])
GO
ALTER TABLE [dbo].[Постояльцы] CHECK CONSTRAINT [FK_Постояльцы_НомернойФонд]
GO

-- %% [markdown]
-- # [FK_Постояльцы_Пользователи]

-- %%
ALTER TABLE [dbo].[Постояльцы]  WITH CHECK ADD  CONSTRAINT [FK_Постояльцы_Пользователи] FOREIGN KEY([IDСотрудник])
REFERENCES [dbo].[Пользователи] ([ID])
GO
ALTER TABLE [dbo].[Постояльцы] CHECK CONSTRAINT [FK_Постояльцы_Пользователи]
GO
